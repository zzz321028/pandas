# %%
import pandas as pd

# %%
df = pd.read_csv('ratings.csv',index_col=None)
result = df.groupby(['rating']).size() # size 返回分组字段的出现次数

# %%
df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
result
# Out:
# rating
# 0.5     1370
# 1.0     2811
# 1.5     1791
# 2.0     7551
# 2.5     5550
# 3.0    20047
# 3.5    13136
# 4.0    26818
# 4.5     8551
# 5.0    13211
# dtype: int64

# %%
df['comment'] = df['rating'].apply(lambda x: '推荐' if x >= 4 else '不推荐')

# %%
df[:50]
# Out:
#     userId  movieId  rating  timestamp comment
# 0        1        1     4.0  964982703      推荐
# 1        1        3     4.0  964981247      推荐
# 2        1        6     4.0  964982224      推荐
# 3        1       47     5.0  964983815      推荐
# 4        1       50     5.0  964982931      推荐
# 5        1       70     3.0  964982400     不推荐
# 6        1      101     5.0  964980868      推荐
# 7        1      110     4.0  964982176      推荐
# 8        1      151     5.0  964984041      推荐
# 9        1      157     5.0  964984100      推荐
# 10       1      163     5.0  964983650      推荐
# 11       1      216     5.0  964981208      推荐
# 12       1      223     3.0  964980985     不推荐
# 13       1      231     5.0  964981179      推荐
# 14       1      235     4.0  964980908      推荐
# 15       1      260     5.0  964981680      推荐
# 16       1      296     3.0  964982967     不推荐
# 17       1      316     3.0  964982310     不推荐
# 18       1      333     5.0  964981179      推荐
# ...

# %%
df.to_csv('comment.csv', index = False)

# %%
df1 = pd.read_csv('comment.csv')

# %%
df1
# Out:
#         userId  movieId  rating   timestamp comment
# 0            1        1     4.0   964982703      推荐
# 1            1        3     4.0   964981247      推荐
# 2            1        6     4.0   964982224      推荐
# 3            1       47     5.0   964983815      推荐
# 4            1       50     5.0   964982931      推荐
# ...        ...      ...     ...         ...     ...
# 100831     610   166534     4.0  1493848402      推荐
# 100832     610   168248     5.0  1493850091      推荐
# 100833     610   168250     5.0  1494273047      推荐
# 100834     610   168252     5.0  1493846352      推荐
# 100835     610   170875     3.0  1493846415     不推荐
#
# [100836 rows x 5 columns]
